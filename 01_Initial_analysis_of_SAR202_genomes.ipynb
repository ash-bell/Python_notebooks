# %%
import glob
from Bio import SeqIO
import pandas as pd
import numpy as np
import os

out_seqs = []
records = []

for file in glob.glob('/disk2/projects/TempertonLab/SAR202/data/fasta/*.fasta'):
    seq_name = os.path.basename(file).replace('.fasta', '')
    with open(file, 'r') as handle:
        seq_lengths = []
        for record in SeqIO.parse(handle, 'fasta'):
            record.id = '%s_%s' % (seq_name, record.id)
            record.description=''
            seq_lengths.append(len(record.seq))
            out_seqs.append(record)
        records.append((seq_name, len(seq_lengths), np.sum(seq_lengths)/1e6, np.min(seq_lengths), np.max(seq_lengths)))

SeqIO.write(out_seqs, '/disk2/projects/TempertonLab/SAR202/scratch/combined.seqs.fa', 'fasta')
df = pd.DataFrame(records, columns=['seq_name', 'number_of_contigs', 'total_length_Mbp', 'shortest_contig', 'longest_contig_length'])
df = df.sort_values('total_length_Mbp', ascending=False)
df
# Out:
#      seq_name  number_of_contigs  total_length_Mbp  shortest_contig  \
# 4      MPNC01                 67          4.958136             1702
# 17     MPND01                213          4.606320             1084
# 62     MPMM01                 58          4.393250             1778
# 27   OSU_TB21                251          3.950169             2507
# 90   OSU_TB15                299          3.936920             2511
# 36     MPMJ01                101          3.223809             1149
# 73   OSU_TB65                 82          3.121826             2553
# 115  OSU_TB22                 69          3.094065             2952
# 61     MPNN01                 21          3.017767             3194
# 69   UM_GB_B1                 73          2.998127             5396
# 83   OSU_TB47                323          2.671503             2559
# 14   OSU_TB24                148          2.651326             2501
# 75   OSU_TB59                190          2.629155             2500
# 94   OSU_TB09                186          2.609057             2505
# 100  OSU_TB17                305          2.602142             2504
# 3    OSU_TB13                318          2.592751             2502
# 19   OSU_TB10                442          2.577089             2500
# 98   OSU_TB28                353          2.558021             2517
# 109  OSU_TB61                279          2.532689             2517
# 57   OSU_TB38                133          2.491678             2500
# 82   USC_TB81                 30          2.484032            15784
# 53   LSU_GOM1                179          2.475308             3002
# 12   OSU_TB25                250          2.461216             2504
# 21   OSU_TB48                420          2.436464             2501
# 111  OSU_TB63                121          2.275237             2504
# 43   OSU_TB52                384          2.179823             2514
# 6    OSU_TB01                 99          2.173708             2560
# 66   OSU_TB26                294          2.120711             2513
# 68   OSU_TB29                344          2.081632             2521
# 1    OSU_TB39                 67          2.053070             2717
# ..        ...                ...               ...              ...
# 10   OSU_TB43                 79          1.242821             2506
# 60   OSU_TB20                 88          1.240037             2514
# 67   OSU_TB04                196          1.227201             2500
# 52   USC_TB74                 32          1.219234             5181
# 47   OSU_TB60                200          1.190977             2503
# 87   OSU_TB30                136          1.186805             2510
# 80   USC_TB72                 71          1.185111             8522
# 112  OSU_TB58                130          1.177170             2545
# 23   OSU_NS03                113          1.123826             1505
# 39   OSU_TB33                 35          1.114687             2576
# 119  USC_TB86                 13          1.097020            16182
# 81   OSU_ZL02                 70          1.096525             2011
# 24   USC_TB68                 31          1.060569             7661
# 92   USC_TB78                 12          1.059703            18680
# 33   OSU_NS09                 56          1.047363             2052
# 18   OSU_NS08                 53          1.028817             2001
# 84   USC_TB76                 13          1.018053            30019
# 51   USC_TB82                 25          0.981310            15183
# 105  OSU_NS04                 84          0.848920             1568
# 78   OSU_NS05                136          0.835250             1502
# 102  OSU_TB08                109          0.823553             2504
# 0    OSU_BB07                126          0.823410             2513
# 11   OSU_ZL05                 39          0.807656             2026
# 20   OSU_TB49                126          0.779111             2501
# 114  OSU_TB34                 23          0.751477             2567
# 70   OSU_TB50                170          0.733192             2500
# 54   OSU_TB46                172          0.705698             2523
# 121  OSU_NS02                 66          0.686135             1580
# 26   OSU_NS07                 48          0.301080             1507
# 29   OSU_NS01                 17          0.287667             2884
#
#      longest_contig_length
# 4                   757257
# 17                  169007
# 62                 1117843
# 27                  106794
# 90                   67435
# 36                  202044
# 73                  312586
# 115                 284945
# 61                  507178
# 69                  329954
# 83                   55796
# 14                   75855
# 75                  103034
# 94                   81662
# 100                  46257
# 3                    72989
# 19                   31640
# 98                   31923
# 109                  46805
# 57                  122121
# 82                  243693
# 53                   90503
# 12                   42710
# 21                   24799
# 111                 248569
# 43                   24008
# 6                   180646
# 66                   40245
# 68                   35000
# 1                   292592
# ..                     ...
# 10                   91464
# 60                  100285
# 67                   37925
# 52                  259121
# 47                   22497
# 87                   51922
# 80                   45180
# 112                  46274
# 23                   67926
# 39                  121213
# 119                 413184
# 81                  166556
# 24                  128636
# 92                  220105
# 33                   88749
# 18                  209930
# 84                  239051
# 51                  101736
# 105                  62972
# 78                   36741
# 102                  59356
# 0                    25637
# 11                  118480
# 20                   38621
# 114                 269253
# 70                   12752
# 54                   12289
# 121                  57437
# 26                   30312
# 29                   69605
#
# [122 rows x 5 columns]

# %% [markdown]
# Now we run VirSorter

# %%
# !cd /disk2/projects/TempertonLab/SAR202/scratch
# !wrapper_phage_contigs_sorter_iPlant.pl \
-f combined.seqs.fa \
--db 2 \
--wdir virsorter \
--ncpu 16 \
--data-dir /disk2/dbs/virsorter-data

# %%
import pandas as pd
import numpy as np

out_phage = open('/disk2/projects/TempertonLab/SAR202/scratch/phage.csv', 'w')
out_prophage = open('/disk2/projects/TempertonLab/SAR202/scratch/prophage.csv', 'w')
phage=True

#split the virsorter output into two sections so we can re-label 1-3 with 4-6 for prophage
with open('/disk2/projects/TempertonLab/SAR202/scratch/virsorter/VIRSorter_global-phage-signal.csv', 'r') as handle:
    for line in handle.readlines():
        if line.startswith('## 4'):
            phage=False
        if phage:
            out_phage.write(line)
        else:
            out_prophage.write(line)
out_phage.close()
out_prophage.close()
            

phage_df = pd.read_csv('/disk2/projects/TempertonLab/SAR202/scratch/phage.csv',
                          names=['contig',
                                'num_genes',
                                 'fragment',
                                'virsorter_category'],
                          usecols=[0, 1,2,4],
                          comment='#')

prophage_df = pd.read_csv('/disk2/projects/TempertonLab/SAR202/scratch/prophage.csv',
                          names=['contig',
                                'num_genes',
                                 'fragment',
                                'virsorter_category'],
                          usecols=[0, 1,2,4],
                          comment='#')

prophage_df['virsorter_category'] = prophage_df['virsorter_category'] + 3

def is_circular(row):
    return 'circular' in row['contig']

virsorter_df = phage_df.append(prophage_df).reset_index().drop(columns=['index'])
virsorter_df['is_circular'] = virsorter_df.apply(is_circular, axis=1)
virsorter_df['contig'] = virsorter_df['contig'].replace([r'VIRSorter_(.*_cov_\d+)_(\d+).*', r'VIRSorter_',
                                                        r'(BSAE-\d{4}-\d)_([A-Z0-9]+)', r'-circular'], 
                                                        [r'\1.\2', '', r'\1.\2', ''], regex=True)
virsorter_df['fragment'] = virsorter_df['fragment'].replace([r'VIRSorter_(.*_cov_\d+)_(\d+).*', 
                                                             r'VIRSorter_', 
                                                             r'(BSAE-\d{4}-\d)_([A-Z0-9]+)', 
                                                            r'-circular'], 
                                                        [r'\1.\2', '', r'\1.\2', ''], regex=True)

# !rm /disk2/projects/TempertonLab/SAR202/scratch/phage.csv /disk2/projects/TempertonLab/SAR202/scratch/prophage.csv
virsorter_df[~virsorter_df['is_circular']]
virsorter_df
# Out:
#                 contig  num_genes                             fragment  \
# 0    USC_TB68_TB68_001         10                    USC_TB68_TB68_001
# 1    USC_TB72_TB72_055         40                    USC_TB72_TB72_055
# 2    LSU_GOM1_GOM1_103         12                    LSU_GOM1_GOM1_103
# 3    LSU_GOM1_GOM1_176         13                    LSU_GOM1_GOM1_176
# 4      MPMJ01_MPMJ_030         51                      MPMJ01_MPMJ_030
# 5      MPMJ01_MPMJ_042         22                      MPMJ01_MPMJ_042
# 6      MPMJ01_MPMJ_057         18                      MPMJ01_MPMJ_057
# 7      MPMM01_MPMM_027         50                      MPMM01_MPMM_027
# 8      MPND01_MPND_161          5                      MPND01_MPND_161
# 9      MPNN01_MPNN_009        114                      MPNN01_MPNN_009
# 10     MPNN01_MPNN_017         31                      MPNN01_MPNN_017
# 11   OSU_BB01_BB01_124          6                    OSU_BB01_BB01_124
# 12   OSU_BB02_BB02_055          6                    OSU_BB02_BB02_055
# 13   OSU_BB03_BB03_050         11                    OSU_BB03_BB03_050
# 14   OSU_NS09_NS09_034          6                    OSU_NS09_NS09_034
# 15   OSU_TB01_TB01_076          7                    OSU_TB01_TB01_076
# 16   OSU_TB05_TB05_130          8                    OSU_TB05_TB05_130
# 17   OSU_TB07_TB07_119         92                    OSU_TB07_TB07_119
# 18   OSU_TB09_TB09_014          6                    OSU_TB09_TB09_014
# 19   OSU_TB09_TB09_060          9                    OSU_TB09_TB09_060
# 20   OSU_TB11_TB11_122          8                    OSU_TB11_TB11_122
# 21   OSU_TB15_TB15_231         10                    OSU_TB15_TB15_231
# 22   OSU_TB19_TB19_103          9                    OSU_TB19_TB19_103
# 23   OSU_TB23_TB23_153          5                    OSU_TB23_TB23_153
# 24   OSU_TB44_TB44_068          6                    OSU_TB44_TB44_068
# 25   OSU_TB45_TB45_001          3                    OSU_TB45_TB45_001
# 26   OSU_TB48_TB48_241          4                    OSU_TB48_TB48_241
# 27   OSU_TB49_TB49_115          6                    OSU_TB49_TB49_115
# 28   OSU_TB56_TB56_001          4                    OSU_TB56_TB56_001
# 29   OSU_TB56_TB56_018          7                    OSU_TB56_TB56_018
# ..                 ...        ...                                  ...
# 170    MPMM01_MPMM_024         35      MPMM01_MPMM_024-gene_11-gene_34
# 171    MPNC01_MPNC_002        644    MPNC01_MPNC_002-gene_582-gene_644
# 172    MPNC01_MPNC_003        508      MPNC01_MPNC_003-gene_26-gene_71
# 173    MPNC01_MPNC_006        227       MPNC01_MPNC_006-gene_1-gene_72
# 174    MPNC01_MPNC_010        127      MPNC01_MPNC_010-gene_3-gene_102
# 175    MPNC01_MPNC_021         41      MPNC01_MPNC_021-gene_21-gene_41
# 176    MPNC01_MPNC_030         17       MPNC01_MPNC_030-gene_2-gene_14
# 177    MPNC01_MPNC_034         20       MPNC01_MPNC_034-gene_8-gene_19
# 178    MPND01_MPND_004        118     MPND01_MPND_004-gene_90-gene_116
# 179    MPND01_MPND_025         43      MPND01_MPND_025-gene_22-gene_38
# 180    MPND01_MPND_047         23       MPND01_MPND_047-gene_5-gene_17
# 181    MPND01_MPND_106         15       MPND01_MPND_106-gene_1-gene_12
# 182    MPNN01_MPNN_002        373    MPNN01_MPNN_002-gene_125-gene_224
# 183    MPNN01_MPNN_006        246       MPNN01_MPNN_006-gene_1-gene_44
# 184    MPNN01_MPNN_016         31      MPNN01_MPNN_016-gene_11-gene_31
# 185  OSU_NS04_NS04_008         29    OSU_NS04_NS04_008-gene_16-gene_29
# 186  OSU_NS10_NS10_013         35    OSU_NS10_NS10_013-gene_11-gene_30
# 187  OSU_TB07_TB07_064         41    OSU_TB07_TB07_064-gene_26-gene_41
# 188  OSU_TB29_TB29_125         14     OSU_TB29_TB29_125-gene_4-gene_14
# 189  OSU_TB39_TB39_063         64    OSU_TB39_TB39_063-gene_17-gene_64
# 190  OSU_ZL04_ZL04_017         54    OSU_ZL04_ZL04_017-gene_28-gene_52
# 191  OSU_ZL04_ZL04_026         15     OSU_ZL04_ZL04_026-gene_5-gene_15
# 192  OSU_ZL04_ZL04_052         63     OSU_ZL04_ZL04_052-gene_4-gene_31
# 193  USC_TB81_TB81_002        246     USC_TB81_TB81_002-gene_1-gene_51
# 194  USC_TB81_TB81_002        246   USC_TB81_TB81_002-gene_82-gene_181
# 195  USC_TB81_TB81_012        233  USC_TB81_TB81_012-gene_130-gene_229
# 196  USC_TB81_TB81_012        233    USC_TB81_TB81_012-gene_9-gene_108
# 197  USC_TB81_TB81_019        205   USC_TB81_TB81_019-gene_72-gene_171
# 198  USC_TB81_TB81_021        159     USC_TB81_TB81_021-gene_6-gene_39
# 199  USC_TB81_TB81_021        159   USC_TB81_TB81_021-gene_60-gene_159
#
#      virsorter_category  is_circular
# 0                     1        False
# 1                     1        False
# 2                     2        False
# 3                     2        False
# 4                     2        False
# 5                     2        False
# 6                     2        False
# 7                     2         True
# 8                     2        False
# 9                     2         True
# 10                    2        False
# 11                    2        False
# 12                    2        False
# 13                    2        False
# 14                    2        False
# 15                    2        False
# 16                    2        False
# 17                    2        False
# 18                    2        False
# 19                    2        False
# 20                    2        False
# 21                    2        False
# 22                    2        False
# 23                    2        False
# 24                    2        False
# 25                    2        False
# 26                    2        False
# 27                    2        False
# 28                    2        False
# 29                    2        False
# ..                  ...          ...
# 170                   6        False
# 171                   6        False
# 172                   6        False
# 173                   6        False
# 174                   6        False
# 175                   6        False
# 176                   6        False
# 177                   6        False
# 178                   6        False
# 179                   6        False
# 180                   6        False
# 181                   6        False
# 182                   6        False
# 183                   6        False
# 184                   6        False
# 185                   6        False
# 186                   6        False
# 187                   6        False
# 188                   6        False
# 189                   6        False
# 190                   6        False
# 191                   6        False
# 192                   6        False
# 193                   6        False
# 194                   6        False
# 195                   6        False
# 196                   6        False
# 197                   6        False
# 198                   6        False
# 199                   6        False
#
# [200 rows x 5 columns]

# %% [markdown]
# Now we run VirFinder

# %%
# !cd /disk2/projects/TempertonLab/SAR202/scratch
# !mkdir virfinder
# !mkdir tmp
# !python /home/bt273/tools/scripts/split_reads.py \
--in_file /disk2/projects/TempertonLab/SAR202/scratch/combined.seqs.fa \
--out_dir tmp \
--reads_per_file 1000

# !for i in ./tmp/group*.fa; \
do OUTNAME=$(basename $i .fa); \
OUTNAME+=.csv; \
echo "$i,virfinder/$OUTNAME" >> to_parse; \
done

# !parallel --colsep ',' /home/bt273/tools/scripts/runVirFinder.R {1} {2} :::: to_parse
# !/home/bt273/tools/scripts/combineVirFinder.R virfinder combined.seqs.virfinder.csv
# !rm -rf virfinder tmp

# %%
import pandas as pd
import numpy as np
virfinder_df = pd.read_csv('/disk2/projects/TempertonLab/SAR202/scratch/combined.seqs.virfinder.csv', 
                           names=['contig', 
                                                                              'length',
                                                                              'virfinder_score',
                                                                             'virfinder_pvalue'],
                          skiprows=1)

# %%
viral_df = virfinder_df.merge(virsorter_df, how='left', on='contig')
def is_viral(row):
    return ((row['virsorter_category']==1 or row['virsorter_category']==2) or
        (row['virfinder_score'] > 0.9 and row['virfinder_pvalue'] <0.05) or
        (row['virfinder_score'] >0.7 and 
             row['virfinder_pvalue'] <0.05 and
            ~np.isnan(row['virsorter_category'])))
        
viral_df['is_viral'] = viral_df.apply(is_viral, axis=1)
viral_df.to_csv('/disk2/projects/TempertonLab/SAR202/data/combined.seqs.viral.check.csv', index=False)

only_viral=viral_df[viral_df['is_viral']].sort_values('length', ascending=False)
print("There are %i contigs that have been identified as viral" % len(only_viral.contig.values))
# Out:
# There are 402 contigs that have been identified as viral

# %%
only_viral.to_csv('/disk2/projects/TempertonLab/SAR202/data/viral.contigs.csv')

# %%
only_viral.head()
print("""
In total there are %i contigs that are high-confidence viral (Virsorter 1245 >10kb).
There are %i contigs > 10kb.""" % (
    only_viral[(only_viral.virsorter_category.isin([1,2,4,5])) &
                 (only_viral.length > 10000)].shape[0], 
      only_viral[only_viral.length > 10000].shape[0]))
# Out:
# In total there are 24 contigs that are high-confidence viral (Virsorter 1245 >10kb).
# There are 52 contigs > 10kb.

# %%
402 - only_viral[only_viral.length > 5000].shape[0]
# Out:
# 227

# %%
only_viral[(only_viral.virsorter_category.isin([1,2,4,5])) &
                 (only_viral.length > 10000)]
# Out:
#                   contig  length  virfinder_score  virfinder_pvalue  \
# 4007   OSU_TB57_TB57_007  152655         0.952741          0.006791
# 4003   OSU_TB57_TB57_009   93671         0.972695          0.004608
# 12694    MPNN01_MPNN_009   89568         0.898420          0.013461
# 10686  USC_TB94_TB94_020   52670         0.912485          0.012248
# 1003   OSU_TB07_TB07_119   49618         0.969444          0.005336
# 12713  USC_TB67_TB67_058   46377         0.842318          0.022678
# 9915     MPMJ01_MPMJ_030   39372         0.558021          0.075431
# 2004   OSU_ZL03_ZL03_105   38812         0.987282          0.002789
# 12723    MPNN01_MPNN_017   36743         0.815375          0.026195
# 12959    MPMM01_MPMM_027   34861         0.422834          0.111691
# 1036   USC_TB72_TB72_055   29269         0.822457          0.025103
# 10190    MPMJ01_MPMJ_042   25348         0.334265          0.145889
# 10788  USC_TB94_TB94_028   24614         0.570002          0.072277
# 12722  USC_TB67_TB67_009   22769         0.817200          0.025709
# 12850  USC_TB67_TB67_001   17670         0.572570          0.071792
# 10818  USC_TB94_TB94_025   17193         0.521482          0.083071
# 9732     MPMJ01_MPMJ_057   16038         0.845544          0.022071
# 10694  OSU_TB56_TB56_024   16028         0.856970          0.020495
# 11684  USC_TB74_TB74_018   12599         0.925090          0.010429
# 8693   USC_TB68_TB68_001   12111         0.938420          0.008732
# 1558   OSU_BB03_BB03_050   11936         0.152649          0.266190
# 967    USC_TB69_TB69_007   11861         0.014596          0.668688
# 12690  LSU_GOM1_GOM1_103   11759         0.905965          0.012733
# 2834   OSU_TB15_TB15_231   11172         0.075252          0.385035
#
#        num_genes           fragment  virsorter_category is_circular  is_viral
# 4007       171.0  OSU_TB57_TB57_007                 2.0       False      True
# 4003        68.0  OSU_TB57_TB57_009                 2.0       False      True
# 12694      114.0    MPNN01_MPNN_009                 2.0        True      True
# 10686       67.0  USC_TB94_TB94_020                 2.0       False      True
# 1003        92.0  OSU_TB07_TB07_119                 2.0       False      True
# 12713       68.0  USC_TB67_TB67_058                 2.0       False      True
# 9915        51.0    MPMJ01_MPMJ_030                 2.0       False      True
# 2004        56.0  OSU_ZL03_ZL03_105                 2.0       False      True
# 12723       31.0    MPNN01_MPNN_017                 2.0       False      True
# 12959       50.0    MPMM01_MPMM_027                 2.0        True      True
# 1036        40.0  USC_TB72_TB72_055                 1.0       False      True
# 10190       22.0    MPMJ01_MPMJ_042                 2.0       False      True
# 10788       21.0  USC_TB94_TB94_028                 2.0       False      True
# 12722       30.0  USC_TB67_TB67_009                 2.0       False      True
# 12850       22.0  USC_TB67_TB67_001                 2.0       False      True
# 10818       22.0  USC_TB94_TB94_025                 2.0       False      True
# 9732        18.0    MPMJ01_MPMJ_057                 2.0       False      True
# 10694       36.0  OSU_TB56_TB56_024                 2.0       False      True
# 11684       21.0  USC_TB74_TB74_018                 2.0       False      True
# 8693        10.0  USC_TB68_TB68_001                 1.0       False      True
# 1558        11.0  OSU_BB03_BB03_050                 2.0       False      True
# 967         12.0  USC_TB69_TB69_007                 2.0       False      True
# 12690       12.0  LSU_GOM1_GOM1_103                 2.0       False      True
# 2834        10.0  OSU_TB15_TB15_231                 2.0       False      True

# %% [markdown]
# I think that there is evidence here that VirFinder is struggling with 'new', even in short-read data, so for now, I want to focus on the analysis of the 24 viral contigs identified by VirSorter, and maybe we can come back to those others later. It's very cool to see that OSU_ZL03_ZL03_105 is a phage from a single cell from Zach's work.
#
# Let's pull out the data we need:

# %%
from Bio import SeqIO

hq_sar202_phage = only_viral[(only_viral.virsorter_category.isin([1,2,4,5])) &
                 (only_viral.length > 10000)]

seqs = SeqIO.index('/disk2/projects/TempertonLab/SAR202/scratch/combined.seqs.fa', 'fasta')
out_seqs = [seqs[x] for x in hq_sar202_phage.contig.values]
#len(out_seqs)
SeqIO.write(out_seqs, '/disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.fa', 'fasta')
# Out:
# 24

# %%
out_gbk = []
! sed -i "s/VIRSorter_//g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-1.gb
! sed -i "s/-circular//g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-1.gb

! sed -i "s/VIRSorter_//g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-2.gb
! sed -i "s/-circular//g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-2.gb
! sed -i "s/07\/24\/18/24-Jul-2018/g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-1.gb
! sed -i "s/07\/24\/18/24-Jul-2018/g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-2.gb
! sed -i "s/dna/DNA/g" /disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-2.gb

for record in SeqIO.parse('/disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-1.gb', 'genbank'):
    if record.id in hq_sar202_phage.contig.values:
        out_gbk.append(record)

for record in SeqIO.parse('/disk2/projects/TempertonLab/SAR202/scratch/virsorter/Predicted_viral_sequences/VIRSorter_cat-2.gb', 'genbank'):
    if record.id in hq_sar202_phage.contig.values:
        out_gbk.append(record)

SeqIO.write(out_gbk, '/disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.gbk', 'genbank')
# Out:
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB72_TB72_055        29269 bp    dna     linear   ENV 24-07-2018\n'
# Found locus 'USC_TB72_TB72_055' size '29269' residue_type 'dna'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB68_TB68_001        12111 bp    dna     linear   ENV 24-07-2018\n'
# Found locus 'USC_TB68_TB68_001' size '12111' residue_type 'dna'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB57_TB57_007       152655 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB57_TB57_007' size '152655' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB57_TB57_009        93671 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB57_TB57_009' size '93671' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB94_TB94_020        52670 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB94_TB94_020' size '52670' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB07_TB07_119        49618 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB07_TB07_119' size '49618' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB67_TB67_058        46377 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB67_TB67_058' size '46377' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_ZL03_ZL03_105        38812 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_ZL03_ZL03_105' size '38812' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB94_TB94_028        24614 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB94_TB94_028' size '24614' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB67_TB67_009        22769 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB67_TB67_009' size '22769' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB67_TB67_001        17670 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB67_TB67_001' size '17670' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB94_TB94_025        17193 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB94_TB94_025' size '17193' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB56_TB56_024        16028 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB56_TB56_024' size '16028' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB74_TB74_018        12599 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB74_TB74_018' size '12599' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_BB03_BB03_050        11936 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_BB03_BB03_050' size '11936' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB69_TB69_007        11861 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB69_TB69_007' size '11861' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       LSU_GOM1_GOM1_103        11759 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'LSU_GOM1_GOM1_103' size '11759' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB15_TB15_231        11172 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB15_TB15_231' size '11172' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB72_TB72_005         9844 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB72_TB72_005' size '9844' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB69_TB69_023         8574 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB69_TB69_023' size '8574' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       USC_TB67_TB67_057         8222 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'USC_TB67_TB67_057' size '8222' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_BB02_BB02_055         7540 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_BB02_BB02_055' size '7540' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB05_TB05_130         7513 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB05_TB05_130' size '7513' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB19_TB19_103         7137 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB19_TB19_103' size '7137' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_BB01_BB01_124         6867 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_BB01_BB01_124' size '6867' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB01_TB01_076         6834 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB01_TB01_076' size '6834' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_ZL01_ZL01_053         6663 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_ZL01_ZL01_053' size '6663' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB44_TB44_068         6338 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB44_TB44_068' size '6338' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       LSU_GOM1_GOM1_176         6186 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'LSU_GOM1_GOM1_176' size '6186' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_NS09_NS09_034         5842 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_NS09_NS09_034' size '5842' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_ZL05_ZL05_032         5520 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_ZL05_ZL05_032' size '5520' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB56_TB56_053         5404 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB56_TB56_053' size '5404' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB11_TB11_122         5048 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB11_TB11_122' size '5048' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB49_TB49_115         4981 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB49_TB49_115' size '4981' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB56_TB56_018         4609 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB56_TB56_018' size '4609' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB23_TB23_153         4451 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB23_TB23_153' size '4451' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB09_TB09_014         3898 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB09_TB09_014' size '3898' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB48_TB48_241         3465 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB48_TB48_241' size '3465' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB09_TB09_060         3088 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB09_TB09_060' size '3088' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB45_TB45_001         2772 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB45_TB45_001' size '2772' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/GenBank/Scanner.py:1368: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       OSU_TB56_TB56_001         2587 bp    DNA     linear   ENV 24-Jul-2018\n'
# Found locus 'OSU_TB56_TB56_001' size '2587' residue_type 'DNA'
# Some fields may be wrong.
#   BiopythonParserWarning)
# /home/bt273/anaconda3/lib/python3.6/site-packages/Bio/SeqIO/InsdcIO.py:600: BiopythonWarning: Stealing space from length field to allow long name in LOCUS line
#   warnings.warn("Stealing space from length field to allow long name in LOCUS line", BiopythonWarning)
# 24

# %% [markdown]
# Now I need to the viral predicted protein sequences and blasting them against NR to work out both their function and their taxonomy

# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import IUPAC
prots = []
for record in SeqIO.parse('/disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.gbk','genbank'):
    if record.features:
        for feature in record.features:
            if feature.type == "CDS":
                prots.append(SeqRecord(
                    feature.location.extract(record).seq, 
                    id=feature.qualifiers['locus_tag'][0], description=''))
SeqIO.write(prots, '/disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.prots.faa', 'fasta')
# Out:
# 1055

# %% [markdown]
# Now we can run these against NR

# %%
# !diamond blastp --threads 16 \
--db /disk2/dbs/ncbi/nr.dmnd \
--out /disk2/projects/TempertonLab/SAR202/scratch/sar202.viral.contigs.10k.cat12.prots.vs.nr.out.gz \
--outfmt 6 qseqid sseqid stitle staxids pident length qstart qend sstart send evalue \
--query /disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.prots.faa \
-k 500 \
--more-sensitive \
--compress 1 \
--subject-cover 20 \
--evalue 1e-5

# %% [markdown]
# # Annotating with Prokka
#
# We want to run prokka on each contig individually, then recombine them so that we can keep the contig name and the locus name sensible.
#
# We're going to annotate them against dsDNA phage genomes that are known to infect bacteria:
# ```bash
# Viruses[Organism] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost bacteria"[Filter])
# ```
#
# ```bash
# prokka --outdir /disk2/projects/TempertonLab/SAR202/data/prokka \
# --force \
# --kingdom Viruses \
# --addgenes \
# --mincontiglen 200 \
# --centre XXX \
# --metagenome \
# --cdsrnaolap \
# --cpus 16 \
# --rfam \
# --proteins /disk2/dbs/ncbi/refseq/refseq.viral.v85.gpff \
# /disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.fa
# ```

# %%
from Bio import SeqIO
import subprocess


for record in SeqIO.parse('/disk2/projects/TempertonLab/SAR202/data/sar202.viral.contigs.10k.cat12.fa', 'fasta'):
    SeqIO.write([record], 'tmp.fa', 'fasta')
    cmd = """
    prokka --outdir /disk2/projects/TempertonLab/SAR202/scratch/%s --force \
    --compliant \
    --prefix %s \
    --centre Z \
    --kingdom Virus \
    --metagenome \
    --cdsrnaolap \
    --cpus 16 \
    --rfam \
    --genus "Putative_SAR202_phage" \
    --locustag %s_gene_ \
    --proteins /disk2/dbs/ncbi/refseq/dsDNA.phage.gb \
    --hmms /disk2/dbs/vFAM/vFam-B_2014.hmm \
    tmp.fa
    """ % (record.id, record.id, record.id)
    subprocess.call(cmd.split())

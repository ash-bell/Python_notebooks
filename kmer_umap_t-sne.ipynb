# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/minion/tools/marine-phage-paper-scripts/wgs_sag_edit.umap.tsv", sep = "\t")

# %%
df
# Out:
#                                read   length        D1        D2 Phylogeny
# 0                              AAAA   666596  8.220217 -4.972123       NaN
# 1                              AAAB   215518 -2.707548 -3.975113       NaN
# 2                              AAAC   918292  8.725930  0.735481       NaN
# 3                              AAAD   249685 -5.096164  3.234056       NaN
# 4                              AAAE   497031  5.338861  4.134761       NaN
# 5                              AAAF   431472  5.777588  4.082194       NaN
# 6                              AAAG   823623  6.377314  3.420397       NaN
# 7                              AAAH   266067  0.163224 -3.529774       NaN
# 8                              AAAI   212223  7.990721  3.577531       NaN
# 9                              AAAJ   532349 -3.345608 -4.086304       NaN
# 10                             AAAK   775383  6.645096  3.341340       NaN
# ...

# %%
cmaps = 
plt.scatter(df.D1, df.D2, s=1, c=colours)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: (nan, None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4273                 # must be acceptable as PathCollection facecolors
# -> 4274                 colors = mcolors.to_rgba_array(c)
#    4275             except ValueError:
#
# ...
